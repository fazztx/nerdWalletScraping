# %% [markdown]
# # NerdWallet Web Scraping Tool
#
# ### ETL tool to display high yield online savings account

# %%
import pandas as pd
import numpy as np

import re

URL = "https://www.nerdwallet.com/best/banking/high-yield-online-savings-accounts"

# %% [markdown]
# #### Preview data below

# %%
allTables = pd.read_html(URL) #All tables is a list with all the tables featured on the URL
df = pd.DataFrame(allTables[1]) 
df #To preview table
# Out:
#                           Financial Institution
# 0            Zynlo Bank, funds insured by FDIC.  \
# 1                  Santander Bank, Member FDIC.
# 2                     Newtek Bank, Member FDIC.
# 3   EverBank (formerly TIAA Bank), Member FDIC.
# 4               My Banking Direct, Member FDIC.
# 5                  Forbright Bank, Member FDIC.
# 6                      Poppy Bank, Member FDIC.
# 7                Western Alliance, Member FDIC.
# 8           Jenius Bank, funds insured by FDIC.
# 9                        TAB Bank, Member FDIC.
# 10       Bread Savings™, funds insured by FDIC.
# 11                 Popular Direct, Member FDIC.
# 12          First Foundation Bank, Member FDIC.
# 13                      Bask Bank, Member FDIC.
# 14                     UFB Direct, Member FDIC.
# 15                    LendingClub, Member FDIC.
# 16                       CIT Bank, Member FDIC.
# 17              Upgrade, funds insured by FDIC.
# 18                       BMO Alto, Member FDIC.
# 19                       Barclays, Member FDIC.
# 20                   Quontic Bank, Member FDIC.
# 21              Salem Five Direct, Member FDIC.
# 22                Sallie Mae Bank, Member FDIC.
# 23                           SoFi, Member FDIC.
# 24                 Synchrony Bank, Member FDIC.
# 25                  Live Oak Bank, Member FDIC.
# 26        Marcus by Goldman Sachs, Member FDIC.
# 27                       Citizens, Member FDIC.
# 28               American Express, Member FDIC.
# 29                       Citibank, Member FDIC.
# 30                 Discover® Bank, Member FDIC.
# 31                Capital One 360, Member FDIC.
#
#    NerdWallet Overall Institution Rating
# 0                                   4.6.  \
# 1                                   4.0.
# 2                                   4.6.
# 3                                   4.4.
# 4                                   4.5.
# 5                                   4.4.
# 6                                   4.3.
# 7                                   4.3.
# 8                                   4.9.
# 9                                   4.5.
# 10                                  4.8.
# 11                                  4.2.
# 12                                  3.8.
# 13                                  4.5.
# 14                                  4.9.
# 15                                  4.5.
# 16                                  4.4.
# 17                                  4.6.
# 18                                  4.7.
# 19                                  4.2.
# 20                                  4.4.
# 21                                  4.5.
# 22                                  4.0.
# 23                                  4.9.
# 24                                  4.9.
# 25                                  4.0.
# 26                                  4.8.
# 27                                  4.5.
# 28                                  4.6.
# 29                                  4.3.
# 30                                  5.0.
# 31                                  4.6.
#
#                                                   APY
# 0                                              5.00%.  \
# 1   4.75%.Santander Bank disclosuresSantander Bank...
# 2                                              4.90%.
# 3                                              4.40%.
# 4                                              4.65%.
# 5                                              4.60%.
# 6                                              4.75%.
# 7                                              4.46%.
# 8                                              4.80%.
# 9                                              4.37%.
# 10  4.50%.Bread Savings disclosureBread Savings ad...
# 11                                             4.60%.
# 12                                             4.50%.
# 13                                             4.50%.
# 14                                             4.01%.
# 15     3.75% (4.75% if certain requirements are met).
# 16                                             4.35%.
# 17                                             4.14%.
# 18                                             4.30%.
# 19                                             4.35%.
# 20                                             3.85%.
# 21                                             4.25%.
# 22                                             4.10%.
# 23            4.00% (variable and subject to change).
# 24                                             4.10%.
# 25                                             4.20%.
# 26  3.90% APY (annual percentage yield) as of 12/0...
# 27                                             3.70%.
# 28  3.80% APY (annual percentage yield) as of 12/1...
# 29                                             3.80%.
# 30                                             3.75%.
# 31                                             3.80%.
#
#             Minimum balance to open
# 0      $10 minimum to open account.
# 1     $500 minimum to open account.
# 2       No minimum to open account.
# 3       No minimum to open account.
# 4     $500 minimum to open account.
# 5       No minimum to open account.
# 6       No minimum to open account.
# 7     $500 minimum to open account.
# 8       No minimum to open account.
# 9       No minimum to open account.
# 10    $100 minimum to open account.
# 11            $100 minimum to open.
# 12  $1,000 minimum to open account.
# 13      No minimum to open account.
# 14      No minimum to open account.
# 15      No minimum to open account.
# 16    $100 minimum to open account.
# 17      No minimum to open account.
# 18      No minimum to open account.
# 19      No minimum to open account.
# 20    $100 minimum to open account.
# 21     $10 minimum to open account.
# 22      No minimum to open account.
# 23      No minimum to open account.
# 24      No minimum to open account.
# 25      No minimum to open account.
# 26      No minimum to open account.
# 27   $0.01 minimum to open account.
# 28            Minimum to open = $0.
# 29      No minimum to open account.
# 30      No minimum to open account.
# 31      No minimum to open account.

# %% [markdown]
# #### Keeping relevant columns

# %%
df = df[['Financial Institution', 'APY', 'Minimum balance to open']] #To erase nerdwallet rating

# %% [markdown]
# #### Removing 'FDIC' from bank name

# %%
data = df['Financial Institution']

i=0
while len(data) > i:
    s = str(data[i])

    #block below from copilot
    match = re.match(r'([^,]+),', s) 
    if match: 
        substring = match.group(1) 
        data[i] = substring
    i += 1
# Out:
# C:\Users\igabx\AppData\Local\Temp\ipykernel_5284\3807050580.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = substring

# %% [markdown]
# #### Renaming APY column

# %%
df.rename(columns={"APY": "APY (%)"}, inplace=True)
# Out:
# C:\Users\igabx\AppData\Local\Temp\ipykernel_5284\1474066756.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={"APY": "APY (%)"}, inplace=True)

# %% [markdown]
# #### Removing percentage from each APY row

# %%
data = df['APY (%)']

i=0
while len(data) > i:
    s = str(data[i])

    #block below from copilot
    match = re.match(r'([^%]+)%', s) 
    if match: 
        substring = match.group(1) 
        data[i] = substring
    i += 1
# Out:
# C:\Users\igabx\AppData\Local\Temp\ipykernel_5284\2905830238.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = substring

# %% [markdown]
# #### Deleting redundancy in balance rows

# %%
data = df['Minimum balance to open']

i=0
while len(data) > i:
    s = str(data[i])

    match = re.match(r'\$\d+(\.\d{2})?', s) #One liner from Copilot

    if match:
        substring = match.group(0)
        data[i] = substring

    else:
        data[i] = ""
    
    i+=1
# Out:
# C:\Users\igabx\AppData\Local\Temp\ipykernel_5284\2461200819.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = substring
# C:\Users\igabx\AppData\Local\Temp\ipykernel_5284\2461200819.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = ""

# %% [markdown]
# #### Sorting based on highest APY %

# %%
df.sort_values(by=['APY (%)'], ascending=False)
df.head(10)
# Out:
#            Financial Institution APY (%) Minimum balance to open
# 0                     Zynlo Bank    5.00                     $10
# 1                 Santander Bank    4.75                    $500
# 2                    Newtek Bank    4.90
# 3  EverBank (formerly TIAA Bank)    4.40
# 4              My Banking Direct    4.65                    $500
# 5                 Forbright Bank    4.60
# 6                     Poppy Bank    4.75
# 7               Western Alliance    4.46                    $500
# 8                    Jenius Bank    4.80
# 9                       TAB Bank    4.37
